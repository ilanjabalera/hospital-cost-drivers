# %%
import pandas as pd
import numpy as np

np.random.seed(42)

n = 5000  # número de hospitalizaciones

df = pd.DataFrame({
    "encounter_id": range(1, n + 1),
    "age": np.random.randint(18, 90, n),
    "sex": np.random.choice(["Male", "Female"], n),
    "payer": np.random.choice(
        ["Medicare", "Medicaid", "Private", "Self-pay"],
        n,
        p=[0.4, 0.2, 0.3, 0.1]
    ),
    "admission_type": np.random.choice(
        ["Emergency", "Elective", "Urgent"],
        n,
        p=[0.6, 0.25, 0.15]
    ),
    "length_of_stay": np.random.poisson(lam=4, size=n) + 1,
    "diagnosis_group": np.random.choice(
        ["Cardiology", "Endocrinology", "Pulmonology", "Orthopedics", "Neurology"],
        n
    )
})

base_cost = np.random.lognormal(mean=8, sigma=0.7, size=n)

df["total_charges"] = (
    base_cost
    * (1 + df["length_of_stay"] * 0.15)
    * np.where(df["admission_type"] == "Emergency", 1.4, 1.0)
)

df.head()
# Out:
#    encounter_id  age     sex     payer admission_type  length_of_stay  \
# 0             1   69    Male  Medicare       Elective               4
# 1             2   32  Female  Medicare       Elective               6
# 2             3   89    Male  Medicare       Elective               3
# 3             4   78    Male   Private      Emergency               7
# 4             5   38    Male   Private      Emergency               4
#
#   diagnosis_group  total_charges
# 0     Pulmonology    4384.555564
# 1     Orthopedics    4559.744021
# 2      Cardiology    3014.315546
# 3   Endocrinology   20795.605045
# 4   Endocrinology    6052.970564

# %%
import duckdb
import pandas as pd
import numpy as np

print("duckdb:", duckdb.__version__)
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
# Out:
# duckdb: 1.4.4
# pandas: 3.0.1
# numpy: 2.4.2

# %%
output_path = "../data/processed/encounters_clean.csv"
df.to_csv(output_path, index=False)
print("Save in:", output_path)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 2
#       1 output_path = "../data/processed/encounters_clean.csv"
# ----> 2 df.to_csv(output_path, index=False)
#       3 print("Save in:", output_path)
#
# File c:\Users\Ilan\Documents\Hospital Cost Drivers\.venv\Lib\site-packages\pandas\core\generic.py:3988, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3977 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3979 formatter = DataFrameFormatter(
#    3980     frame=df,
#    3981     header=header,
#    (...)   3985     decimal=decimal,
#    3986 )
# -> 3988 return DataFrameRenderer(formatter).to_csv(
#    3989     path_or_buf,
#    3990     lineterminator=lineterminator,
#    3991     sep=sep,
#    3992     encoding=encoding,
#    3993     errors=errors,
#    3994     compression=compression,
#    3995     quoting=quoting,
#    3996     columns=columns,
#    3997     index_label=index_label,
#    3998     mode=mode,
#    3999     chunksize=chunksize,
#    4000     quotechar=quotechar,
#    4001     date_format=date_format,
#    4002     doublequote=doublequote,
#    4003     escapechar=escapechar,
#    4004     storage_options=storage_options,
#    4005 )
#
# File c:\Users\Ilan\Documents\Hospital Cost Drivers\.venv\Lib\site-packages\pandas\io\formats\format.py:1025, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1004     created_buffer = False
#    1006 csv_formatter = CSVFormatter(
#    1007     path_or_buf=path_or_buf,
#    1008     lineterminator=lineterminator,
#    (...)   1023     formatter=self.fmt,
#    1024 )
# -> 1025 csv_formatter.save()
#    1027 if created_buffer:
#    1028     assert isinstance(path_or_buf, StringIO)
#
# File c:\Users\Ilan\Documents\Hospital Cost Drivers\.venv\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     # error: Argument "quoting" to "writer" has incompatible type "int";
#     261     # expected "Literal[0, 1, 2, 3]"
#     262     self.writer = csvlib.writer(
#     263         handles.handle,
#     264         lineterminator=self.lineterminator,
#    (...)    269         quotechar=self.quotechar,
#     270     )
#     272     self._save()
#
# File c:\Users\Ilan\Documents\Hospital Cost Drivers\.venv\Lib\site-packages\pandas\io\common.py:793, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     791 # Only for write methods
#     792 if "r" not in mode and is_path:
# --> 793     check_parent_directory(str(handle))
#     795 if compression:
#     796     if compression != "zstd":
#     797         # compression libraries do not like an explicit text-mode
#
# File c:\Users\Ilan\Documents\Hospital Cost Drivers\.venv\Lib\site-packages\pandas\io\common.py:652, in check_parent_directory(path)
#     650 parent = Path(path).parent
#     651 if not parent.is_dir():
# --> 652     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: '..\data\processed'

# %%
import os

os.getcwd()
# Out:
# 'c:\\Users\\Ilan\\Documents\\Hospital Cost Drivers\\Notebooks'

# %%
os.listdir("..")
# Out:
# ['.gitignore',
#  '.venv',
#  'DATA',
#  'Notebooks',
#  'README.md',
#  'Reports',
#  'Requirements.txt',
#  'SQL',
#  'src']

# %%
os.listdir("../data")
# Out:
# ['Raw']

# %%
df.to_csv("../data/processed/encounters_clean.csv", index=False)
print("CSV correctly saved")
# Out:
# CSV correctly saved

# %%
import duckdb

# create local base DuckDB 
con = duckdb.connect("health.db")
con

# %%
con.execute("""
CREATE OR REPLACE TABLE encounters AS
SELECT *
FROM read_csv_auto('../data/processed/encounters_clean.csv')
""")

# %%
con.execute("SELECT COUNT(*) FROM encounters").fetchall()
# Out:
# [(5000,)]

# %%
con.execute("SELECT * FROM encounters LIMIT 5").df()
# Out:
#    encounter_id  age     sex     payer admission_type  length_of_stay  \
# 0             1   69    Male  Medicare       Elective               4
# 1             2   32  Female  Medicare       Elective               6
# 2             3   89    Male  Medicare       Elective               3
# 3             4   78    Male   Private      Emergency               7
# 4             5   38    Male   Private      Emergency               4
#
#   diagnosis_group  total_charges
# 0     Pulmonology    4384.555564
# 1     Orthopedics    4559.744021
# 2      Cardiology    3014.315546
# 3   Endocrinology   20795.605045
# 4   Endocrinology    6052.970564

# %%
pareto = con.execute("""
WITH cost_by_patient AS (
    SELECT
        encounter_id,
        SUM(total_charges) AS patient_cost
    FROM encounters
    GROUP BY encounter_id
),
ranked AS (
    SELECT
        encounter_id,
        patient_cost,
        SUM(patient_cost) OVER () AS total_cost,
        SUM(patient_cost) OVER (
            ORDER BY patient_cost DESC
            ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
        ) AS cumulative_cost
    FROM cost_by_patient
)
SELECT
    encounter_id,
    patient_cost,
    cumulative_cost / total_cost AS cumulative_cost_pct
FROM ranked
ORDER BY patient_cost DESC
""").df()

pareto.head(10)
# Out:
#    encounter_id  patient_cost  cumulative_cost_pct
# 0          1556  64430.760061             0.001547
# 1          2484  61496.190001             0.003024
# 2          1615  61042.086365             0.004489
# 3          2002  59987.335179             0.005929
# 4          1012  59106.463152             0.007349
# 5          3221  59089.197278             0.008767
# 6          1699  58382.638290             0.010169
# 7          3109  56143.788286             0.011517
# 8          2340  54429.497109             0.012824
# 9          1801  54211.338011             0.014126

# %%
pareto[pareto["cumulative_cost_pct"] <= 0.6].shape[0] / pareto.shape[0]
# Out:
# 0.3124

# %%
pareto.to_csv("../reports/tables/pareto_high_cost_patients.csv", index=False)

# %%
import os

os.makedirs("../reports/tables", exist_ok=True)

# %%
pareto.to_csv("../reports/tables/pareto_high_cost_patients.csv", index=False)
print("Pareto coreclty saved")
# Out:
# Pareto coreclty saved

# %%
import pandas as pd

pd.read_csv("../reports/tables/pareto_high_cost_patients.csv").head(5)
# Out:
#    encounter_id  patient_cost  cumulative_cost_pct
# 0          1556  64430.760061             0.001547
# 1          2484  61496.190001             0.003024
# 2          1615  61042.086365             0.004489
# 3          2002  59987.335179             0.005929
# 4          1012  59106.463152             0.007349

# %%
# % de encounters que generan ~60% del costo
pct_60 = (
    pareto[pareto["cumulative_cost_pct"] <= 0.60].shape[0]
    / pareto.shape[0]
)

pct_60
# Out:
# 0.3124

# %%
# mark high-cost encounters (top 30%)
high_cost_threshold = pareto["patient_cost"].quantile(0.70)

high_cost_threshold
# Out:
# np.float64(9389.35834512158)

# %%
high_cost_df = con.execute("""
SELECT
  *
FROM encounters
WHERE total_charges >= (
    SELECT
      quantile_cont(total_charges, 0.70)
    FROM encounters
)
""").df()

high_cost_df.head()
# Out:
#    encounter_id  age     sex     payer admission_type  length_of_stay  \
# 0             4   78    Male   Private      Emergency               7
# 1            11   47  Female  Medicare         Urgent               6
# 2            18   75  Female  Medicare      Emergency               4
# 3            21   76    Male   Private      Emergency               4
# 4            23   77    Male  Medicaid      Emergency               4
#
#   diagnosis_group  total_charges
# 0   Endocrinology   20795.605045
# 1   Endocrinology   10651.035297
# 2   Endocrinology   10852.149192
# 3     Pulmonology    9813.817607
# 4     Pulmonology   12041.926823

# %%
high_cost_df.shape
# Out:
# (1500, 8)

# %%
cohorts = con.execute("""
SELECT
  diagnosis_group,
  admission_type,
  payer,
  CASE
    WHEN length_of_stay <= 2 THEN '0-2 days'
    WHEN length_of_stay <= 5 THEN '3-5 days'
    WHEN length_of_stay <= 10 THEN '6-10 days'
    ELSE '11+ days'
  END AS los_bucket,
  COUNT(*) AS encounters,
  AVG(total_charges) AS avg_charges,
  SUM(total_charges) AS total_charges
FROM encounters
WHERE total_charges >= (
    SELECT quantile_cont(total_charges, 0.70)
    FROM encounters
)
GROUP BY
  diagnosis_group,
  admission_type,
  payer,
  los_bucket
ORDER BY total_charges DESC
""").df()

cohorts.head(10)
# Out:
#   diagnosis_group admission_type     payer los_bucket  encounters  \
# 0       Neurology      Emergency  Medicare  6-10 days          43
# 1      Cardiology      Emergency  Medicare  6-10 days          45
# 2   Endocrinology      Emergency  Medicare  6-10 days          39
# 3      Cardiology      Emergency  Medicare   3-5 days          42
# 4     Pulmonology      Emergency  Medicare   3-5 days          40
# 5       Neurology      Emergency  Medicare   3-5 days          41
# 6   Endocrinology      Emergency  Medicare   3-5 days          37
# 7     Orthopedics      Emergency  Medicare  6-10 days          38
# 8     Pulmonology      Emergency  Medicare  6-10 days          44
# 9      Cardiology      Emergency   Private  6-10 days          33
#
#     avg_charges  total_charges
# 0  18331.924837  788272.768003
# 1  17304.197392  778688.882648
# 2  19597.692149  764309.993794
# 3  16732.146583  702750.156490
# 4  17539.736390  701589.455603
# 5  16399.465039  672378.066587
# 6  17340.326901  641592.095324
# 7  16649.364402  632675.847289
# 8  14053.411266  618350.095699
# 9  17211.048432  567964.598242

# %%
cohorts.to_csv("../reports/tables/high_cost_cohorts.csv", index=False)
print("Saved: high_cost_cohorts.csv")
# Out:
# Saved: high_cost_cohorts.csv

# %%
#High-cost encounters cluster around emergency admissions for Medicare patients with neurological and cardiovascular conditions, particularly when length of stay exceeds 3–5 days.

# %%
con.close()
print("DuckDB connection closed")
# Out:
# DuckDB connection closed
